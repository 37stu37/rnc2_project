# %%
# %config Completer.use_jedi = False
# Out:
#   Unrecognized magic %config.
#
#   Julia does not use the IPython %magic syntax. To interact with the IJulia
#   kernel, use IJulia.somefunction(...), for example. Julia macros, string
#   macros, and functions can be used to accomplish most of the other
#   functionalities of IPython magics.

# %%
@time include("prototype_graph.jl")
# Out:
#   Activating project at `~/Documents/Github/rnc2_project`
# 0.0%┣                                      ┫ 0/100.0k [00:00<-1:-23:-20, -0s/it]
# 0.0%┣                                       ┫ 1/100.0k [00:05<Inf:Inf, InfGs/it]
# 0.0%┣                                        ┫ 2/100.0k [00:05<146:04:54, 5s/it]
# 0.0%┣                                         ┫ 3/100.0k [00:05<75:01:42, 3s/it]
# 0.2%┣                                         ┫ 175/100.0k [00:05<52:08, 32it/s]
# 0.4%┣▏                                        ┫ 379/100.0k [00:06<24:10, 69it/s]
# 0.6%┣▎                                       ┫ 586/100.0k [00:06<15:44, 105it/s]
# 0.7%┣▎                                       ┫ 749/100.0k [00:06<12:24, 133it/s]
# 0.9%┣▍                                       ┫ 943/100.0k [00:06<09:55, 167it/s]
# 1.1%┣▌                                      ┫ 1.1k/100.0k [00:06<08:13, 200it/s]
# 1.3%┣▌                                      ┫ 1.3k/100.0k [00:06<07:11, 229it/s]
# ...
