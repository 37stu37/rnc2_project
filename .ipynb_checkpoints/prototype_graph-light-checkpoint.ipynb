# %% [markdown]
# ### **Load libraries - Julia 1.7**

# %%
using Pkg
Pkg.activate(@__DIR__)
# Out:
#   Activating project at `~/Documents/Github/rnc2_project`

# %%
using Graphs
using GraphPlot
using DataFrames, Random, Distributions, Chain
using Plots
using ProgressBars

# %% [markdown]
# ### **Display example graph and distribution function**

# %% [markdown]
# <img src="prototype_graph.png" width=700 height=1000>

# %%
# representation of flow/runoff from randomised pareto distribution
α = 3
θ = 1000

Pareto(α, θ)
sample = rand(Pareto(α, θ), 1000)

histogram(sample)

# %% [markdown]
# ### **Create functions for the different source node types**

# %%
function river_and_dams(dataframe)
    df = filter(:type_source => x -> (x=="river")||(x=="dam"), dataframe) # keep only type of interest
    df = innerjoin(df[:, Not([:magnitude, :time])], # join the PRESENT source with PAST target - allow to inherit magnitude paramters efficiently
                   df[:, [:target, :magnitude, :time]], 
                   on=:source=>:target)
    @. df.time += 1 # increase internal process time
    
    push!(present, df) # record edges in "present" list
end


function landslides(dataframe, delay)
    df = filter(:type_source => x -> x=="landslide", dataframe)
    # generate new landslide if time has come else wait (assume pareto probability distribution ... which is wrong and to be defined at later stage)
    @. df.magnitude = ifelse(df.time == df.global_time, rand(Pareto(3, 1000)), df.magnitude)
    # reset delay to 3 time units if time has come for a reset (assume delayed of 3 units of time to trigger landslide) or wait
    @. df.time = ifelse(df.time == df.global_time, df.time + delay, df.time)
    
    push!(present, df)
end


function catchment(dataframe, delay)
    # current catchment to river if time has come otherwise wait
    df = filter(:type_source=> x -> x=="catchment", dataframe)
    @. df.magnitude = ifelse(df.time == df.global_time, rand(Pareto(3, 1000)), df.magnitude)
    @. df.time = ifelse(df.time == df.global_time, df.time + delay, df.time)
    push!(present, df)

    # deal with the impact of catchment on rivers by cascading the runoff magnitude to rivers if time has come
    df = filter(:source => x -> x in Set(present[end].target), dataframe)
    # simulate all possible configurations of catchment/river
    df = outerjoin(df, 
                present[end], # catchment behavior
                on=:source=>:target, 
                makeunique=true)
    # if time has come (time > global time), catchment runoff to river ELSE 100 (base line value), 
    @. df.magnitude = ifelse(df.time_1 - delay == df.global_time, # due
                        df.magnitude_1, # magnitude of river is magnitude from catchment
                        100) # else magnitude is a base line value of 100 from catchment
    @. df.time += 1
    # println("df - river / catchment")
    # println(df)
    
    push!(present, df[:, [:source, :target, :type_source, :magnitude, :time, :global_time]])
end


function concatenate_results(list_dataframe)
    cat = reduce(vcat, list_dataframe) 
    gdf = groupby(cat, [:source, :target, :type_source, :time, :global_time])
    present = combine(gdf, [:magnitude] .=> sum; renamecols=false) # sum magnitude on edges to common node (have to watch the magnitude units!)
    return present
end
# Out:
# concatenate_results (generic function with 1 method)

# %% [markdown]
# ### **Time algorithm**

# %%
# set up inital input parameters with (semi) random magnitudes
network = DataFrame(source = ["river1", "river2", "river3", "river4", "river5",
"dam", "river6", "river7", "river8", "river9",
"landslide", "landslide", "river8", "catchment1", "catchment2"], 
target = ["river2", "river3", "river4", "river5",
"dam", "river6", "river7", "river8", "river9", "river10",
"river9", "infrastructure", "infrastructure", "river1", "river2"],
type_source= ["river", "river", "river", "river", "river",
"dam", "river", "river", "river", "river",
"landslide", "landslide", "river", "catchment", "catchment"],
magnitude = [1001.0, 1002.0, 1003.0, 1004.0, 1005.0, 1006.0, 1007.0, 1008.0, 1009.0, 1010.0, 0.0, 0.0, 1009.0, 0.0, 0.0])

global_time = 1
@. network.time = global_time
@. network.global_time = global_time

network
# Out:
# 15×6 DataFrame
#  Row │ source      target          type_source  magnitude  time   global_time
#      │ String      String          String       Float64    Int64  Int64
# ─────┼────────────────────────────────────────────────────────────────────────
#    1 │ river1      river2          river           1001.0      1            1
#    2 │ river2      river3          river           1002.0      1            1
#    3 │ river3      river4          river           1003.0      1            1
#    4 │ river4      river5          river           1004.0      1            1
#    5 │ river5      dam             river           1005.0      1            1
#    6 │ dam         river6          dam             1006.0      1            1
#    7 │ river6      river7          river           1007.0      1            1
#    8 │ river7      river8          river           1008.0      1            1
#    9 │ river8      river9          river           1009.0      1            1
#   10 │ river9      river10         river           1010.0      1            1
#   11 │ landslide   river9          landslide          0.0      1            1
#   12 │ landslide   infrastructure  landslide          0.0      1            1
#   13 │ river8      infrastructure  river           1009.0      1            1
#   14 │ catchment1  river1          catchment          0.0      1            1
#   15 │ catchment2  river2          catchment          0.0      1            1

# %%
# Algorithm #################################
clock = []# will be used to record the time, magnitude of events on the different edges 
push!(clock, network)# add initial state to the records

@time for global_time in 1:87600 #(10 years in hours)

    # println("global time : $global_time")

    global present = [] # empty list to store present 
    past = clock[end]
    @. past.global_time = global_time

    river_and_dams(past)
    landslides(past, 3)
    catchment(past, 10)
    
    present = concatenate_results(present)

    push!(clock, present)
    
end
# Out:
#  32.980955 seconds (157.44 M allocations: 9.670 GiB, 4.60% gc time, 16.76% compilation time)

# %%
clock
# Out:
# 87601-element Vector{Any}:
#  15×6 DataFrame
#  Row │ source      target          type_source  magnitude  time   global_time
#      │ String      String          String       Float64    Int64  Int64
# ─────┼────────────────────────────────────────────────────────────────────────
#    1 │ river1      river2          river           1001.0      1            1
#    2 │ river2      river3          river           1002.0      1            1
#    3 │ river3      river4          river           1003.0      1            1
#    4 │ river4      river5          river           1004.0      1            1
#    5 │ river5      dam             river           1005.0      1            1
#    6 │ dam         river6          dam             1006.0      1            1
#    7 │ river6      river7          river           1007.0      1            1
#    8 │ river7      river8          river           1008.0      1            1
#    9 │ river8      river9          river           1009.0      1            1
#   10 │ river9      river10         river           1010.0      1            1
#   11 │ landslide   river9          landslide          0.0      1            1
#   12 │ landslide   infrastructure  landslide          0.0      1            1
#   13 │ river8      infrastructure  river           1009.0      1            1
#   14 │ catchment1  river1          catchment          0.0      1            1
#   15 │ catchment2  river2          catchment          0.0      1            1
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String      String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river2      river3          river             2            2    3204.76 ⋯
#    2 │ river3      river4          river             2            2    1002.0
#    3 │ river4      river5          river             2            2    1003.0
#    4 │ river5      dam             river             2            2    1004.0
#    5 │ dam         river6          dam               2            2    1005.0  ⋯
#    6 │ river6      river7          river             2            2    1006.0
#    7 │ river7      river8          river             2            2    1007.0
#    8 │ river8      river9          river             2            2    1008.0
#    9 │ river8      infrastructure  river             2            2    1008.0  ⋯
#   10 │ river9      river10         river             2            2    1009.0
#   11 │ landslide   river9          landslide         4            2    1715.25
#   12 │ landslide   infrastructure  landslide         4            2    1213.81
#   13 │ catchment1  river1          catchment        11            2    1284.81 ⋯
#   14 │ catchment2  river2          catchment        11            2    2203.76
#   15 │ river1      river2          river             2            2    1284.81
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river3      river4          river             3            3    3204.76 ⋯
#    2 │ river4      river5          river             3            3    1002.0
#    3 │ river5      dam             river             3            3    1003.0
#    4 │ dam         river6          dam               3            3    1004.0
#    5 │ river6      river7          river             3            3    1005.0  ⋯
#    6 │ river7      river8          river             3            3    1006.0
#    7 │ river8      river9          river             3            3    1007.0
#    8 │ river8      infrastructure  river             3            3    1007.0
#    9 │ river9      river10         river             3            3    1008.0  ⋯
#   10 │ river2      river3          river             3            3    1384.81
#   11 │ landslide   river9          landslide         4            3    1715.25
#   12 │ landslide   infrastructure  landslide         4            3    1213.81
#   13 │ catchment1  river1          catchment        11            3    1284.81 ⋯
#   14 │ catchment2  river2          catchment        11            3    2203.76
#   15 │ river1      river2          river             3            3     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river4      river5          river             4            4    3204.76 ⋯
#    2 │ river5      dam             river             4            4    1002.0
#    3 │ dam         river6          dam               4            4    1003.0
#    4 │ river6      river7          river             4            4    1004.0
#    5 │ river7      river8          river             4            4    1005.0  ⋯
#    6 │ river8      river9          river             4            4    1006.0
#    7 │ river8      infrastructure  river             4            4    1006.0
#    8 │ river9      river10         river             4            4    1007.0
#    9 │ river3      river4          river             4            4    1384.81 ⋯
#   10 │ river2      river3          river             4            4     200.0
#   11 │ landslide   river9          landslide         4            4    1715.25
#   12 │ landslide   infrastructure  landslide         4            4    1213.81
#   13 │ catchment1  river1          catchment        11            4    1284.81 ⋯
#   14 │ catchment2  river2          catchment        11            4    2203.76
#   15 │ river1      river2          river             4            4     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river5      dam             river             5            5    3204.76 ⋯
#    2 │ dam         river6          dam               5            5    1002.0
#    3 │ river6      river7          river             5            5    1003.0
#    4 │ river7      river8          river             5            5    1004.0
#    5 │ river8      river9          river             5            5    1005.0  ⋯
#    6 │ river8      infrastructure  river             5            5    1005.0
#    7 │ river9      river10         river             5            5    1006.0
#    8 │ river4      river5          river             5            5    1384.81
#    9 │ river3      river4          river             5            5     200.0  ⋯
#   10 │ river2      river3          river             5            5     200.0
#   11 │ landslide   river9          landslide         7            5    1193.37
#   12 │ landslide   infrastructure  landslide         7            5    1404.71
#   13 │ catchment1  river1          catchment        11            5    1284.81 ⋯
#   14 │ catchment2  river2          catchment        11            5    2203.76
#   15 │ river1      river2          river             5            5     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ dam         river6          dam               6            6    3204.76 ⋯
#    2 │ river6      river7          river             6            6    1002.0
#    3 │ river7      river8          river             6            6    1003.0
#    4 │ river8      river9          river             6            6    1004.0
#    5 │ river8      infrastructure  river             6            6    1004.0  ⋯
#    6 │ river9      river10         river             6            6    1005.0
#    7 │ river5      dam             river             6            6    1384.81
#    8 │ river4      river5          river             6            6     200.0
#    9 │ river3      river4          river             6            6     200.0  ⋯
#   10 │ river2      river3          river             6            6     200.0
#   11 │ landslide   river9          landslide         7            6    1193.37
#   12 │ landslide   infrastructure  landslide         7            6    1404.71
#   13 │ catchment1  river1          catchment        11            6    1284.81 ⋯
#   14 │ catchment2  river2          catchment        11            6    2203.76
#   15 │ river1      river2          river             6            6     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river6      river7          river             7            7    3204.76 ⋯
#    2 │ river7      river8          river             7            7    1002.0
#    3 │ river8      river9          river             7            7    1003.0
#    4 │ river8      infrastructure  river             7            7    1003.0
#    5 │ river9      river10         river             7            7    1004.0  ⋯
#    6 │ dam         river6          dam               7            7    1384.81
#    7 │ river5      dam             river             7            7     200.0
#    8 │ river4      river5          river             7            7     200.0
#    9 │ river3      river4          river             7            7     200.0  ⋯
#   10 │ river2      river3          river             7            7     200.0
#   11 │ landslide   river9          landslide         7            7    1193.37
#   12 │ landslide   infrastructure  landslide         7            7    1404.71
#   13 │ catchment1  river1          catchment        11            7    1284.81 ⋯
#   14 │ catchment2  river2          catchment        11            7    2203.76
#   15 │ river1      river2          river             7            7     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river7      river8          river             8            8    3204.76 ⋯
#    2 │ river8      river9          river             8            8    1002.0
#    3 │ river8      infrastructure  river             8            8    1002.0
#    4 │ river9      river10         river             8            8    1003.0
#    5 │ river6      river7          river             8            8    1384.81 ⋯
#    6 │ dam         river6          dam               8            8     200.0
#    7 │ river5      dam             river             8            8     200.0
#    8 │ river4      river5          river             8            8     200.0
#    9 │ river3      river4          river             8            8     200.0  ⋯
#   10 │ river2      river3          river             8            8     200.0
#   11 │ landslide   river9          landslide        10            8    1885.2
#   12 │ landslide   infrastructure  landslide        10            8    1052.67
#   13 │ catchment1  river1          catchment        11            8    1284.81 ⋯
#   14 │ catchment2  river2          catchment        11            8    2203.76
#   15 │ river1      river2          river             8            8     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river8      river9          river             9            9    3204.76 ⋯
#    2 │ river8      infrastructure  river             9            9    3204.76
#    3 │ river9      river10         river             9            9    1002.0
#    4 │ river7      river8          river             9            9    1384.81
#    5 │ river6      river7          river             9            9     200.0  ⋯
#    6 │ dam         river6          dam               9            9     200.0
#    7 │ river5      dam             river             9            9     200.0
#    8 │ river4      river5          river             9            9     200.0
#    9 │ river3      river4          river             9            9     200.0  ⋯
#   10 │ river2      river3          river             9            9     200.0
#   11 │ landslide   river9          landslide        10            9    1885.2
#   12 │ landslide   infrastructure  landslide        10            9    1052.67
#   13 │ catchment1  river1          catchment        11            9    1284.81 ⋯
#   14 │ catchment2  river2          catchment        11            9    2203.76
#   15 │ river1      river2          river             9            9     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river            10           10    3204.76 ⋯
#    2 │ river8      river9          river            10           10    1384.81
#    3 │ river8      infrastructure  river            10           10    1384.81
#    4 │ river7      river8          river            10           10     200.0
#    5 │ river6      river7          river            10           10     200.0  ⋯
#    6 │ dam         river6          dam              10           10     200.0
#    7 │ river5      dam             river            10           10     200.0
#    8 │ river4      river5          river            10           10     200.0
#    9 │ river3      river4          river            10           10     200.0  ⋯
#   10 │ river2      river3          river            10           10     200.0
#   11 │ landslide   river9          landslide        10           10    1885.2
#   12 │ landslide   infrastructure  landslide        10           10    1052.67
#   13 │ catchment1  river1          catchment        11           10    1284.81 ⋯
#   14 │ catchment2  river2          catchment        11           10    2203.76
#   15 │ river1      river2          river            10           10     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river            11           11    1384.81 ⋯
#    2 │ river8      river9          river            11           11     200.0
#    3 │ river8      infrastructure  river            11           11     200.0
#    4 │ river7      river8          river            11           11     200.0
#    5 │ river6      river7          river            11           11     200.0  ⋯
#    6 │ dam         river6          dam              11           11     200.0
#    7 │ river5      dam             river            11           11     200.0
#    8 │ river4      river5          river            11           11     200.0
#    9 │ river3      river4          river            11           11     200.0  ⋯
#   10 │ river2      river3          river            11           11     200.0
#   11 │ landslide   river9          landslide        13           11    1033.73
#   12 │ landslide   infrastructure  landslide        13           11    1588.61
#   13 │ catchment1  river1          catchment        11           11    1284.81 ⋯
#   14 │ catchment2  river2          catchment        11           11    2203.76
#   15 │ river1      river2          river            11           11     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river            12           12     200.0  ⋯
#    2 │ river8      river9          river            12           12     200.0
#    3 │ river8      infrastructure  river            12           12     200.0
#    4 │ river7      river8          river            12           12     200.0
#    5 │ river6      river7          river            12           12     200.0  ⋯
#    6 │ dam         river6          dam              12           12     200.0
#    7 │ river5      dam             river            12           12     200.0
#    8 │ river4      river5          river            12           12     200.0
#    9 │ river3      river4          river            12           12     200.0  ⋯
#   10 │ river2      river3          river            12           12    1222.79
#   11 │ landslide   river9          landslide        13           12    1033.73
#   12 │ landslide   infrastructure  landslide        13           12    1588.61
#   13 │ catchment1  river1          catchment        21           12    1460.8  ⋯
#   14 │ catchment2  river2          catchment        21           12    1122.79
#   15 │ river1      river2          river            12           12    1460.8
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river            13           13     200.0  ⋯
#    2 │ river8      river9          river            13           13     200.0
#    3 │ river8      infrastructure  river            13           13     200.0
#    4 │ river7      river8          river            13           13     200.0
#    5 │ river6      river7          river            13           13     200.0  ⋯
#    6 │ dam         river6          dam              13           13     200.0
#    7 │ river5      dam             river            13           13     200.0
#    8 │ river4      river5          river            13           13     200.0
#    9 │ river3      river4          river            13           13    1222.79 ⋯
#   10 │ river2      river3          river            13           13    1560.8
#   11 │ landslide   river9          landslide        13           13    1033.73
#   12 │ landslide   infrastructure  landslide        13           13    1588.61
#   13 │ catchment1  river1          catchment        21           13    1460.8  ⋯
#   14 │ catchment2  river2          catchment        21           13    1122.79
#   15 │ river1      river2          river            13           13     100.0
#  ⋮
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river         87590        87590    1109.22 ⋯
#    2 │ river8      river9          river         87590        87590    1500.53
#    3 │ river8      infrastructure  river         87590        87590    1500.53
#    4 │ river7      river8          river         87590        87590     200.0
#    5 │ river6      river7          river         87590        87590     200.0  ⋯
#    6 │ dam         river6          dam           87590        87590     200.0
#    7 │ river5      dam             river         87590        87590     200.0
#    8 │ river4      river5          river         87590        87590     200.0
#    9 │ river3      river4          river         87590        87590     200.0  ⋯
#   10 │ river2      river3          river         87590        87590     200.0
#   11 │ landslide   river9          landslide     87592        87590    1576.87
#   12 │ landslide   infrastructure  landslide     87592        87590    1021.59
#   13 │ catchment1  river1          catchment     87591        87590    1400.53 ⋯
#   14 │ catchment2  river2          catchment     87591        87590    1009.22
#   15 │ river1      river2          river         87590        87590     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river         87591        87591    1500.53 ⋯
#    2 │ river8      river9          river         87591        87591     200.0
#    3 │ river8      infrastructure  river         87591        87591     200.0
#    4 │ river7      river8          river         87591        87591     200.0
#    5 │ river6      river7          river         87591        87591     200.0  ⋯
#    6 │ dam         river6          dam           87591        87591     200.0
#    7 │ river5      dam             river         87591        87591     200.0
#    8 │ river4      river5          river         87591        87591     200.0
#    9 │ river3      river4          river         87591        87591     200.0  ⋯
#   10 │ river2      river3          river         87591        87591     200.0
#   11 │ landslide   river9          landslide     87592        87591    1576.87
#   12 │ landslide   infrastructure  landslide     87592        87591    1021.59
#   13 │ catchment1  river1          catchment     87591        87591    1400.53 ⋯
#   14 │ catchment2  river2          catchment     87591        87591    1009.22
#   15 │ river1      river2          river         87591        87591     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river         87592        87592     200.0  ⋯
#    2 │ river8      river9          river         87592        87592     200.0
#    3 │ river8      infrastructure  river         87592        87592     200.0
#    4 │ river7      river8          river         87592        87592     200.0
#    5 │ river6      river7          river         87592        87592     200.0  ⋯
#    6 │ dam         river6          dam           87592        87592     200.0
#    7 │ river5      dam             river         87592        87592     200.0
#    8 │ river4      river5          river         87592        87592     200.0
#    9 │ river3      river4          river         87592        87592     200.0  ⋯
#   10 │ river2      river3          river         87592        87592    1166.64
#   11 │ landslide   river9          landslide     87592        87592    1576.87
#   12 │ landslide   infrastructure  landslide     87592        87592    1021.59
#   13 │ catchment1  river1          catchment     87601        87592    1071.15 ⋯
#   14 │ catchment2  river2          catchment     87601        87592    1066.64
#   15 │ river1      river2          river         87592        87592    1071.15
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river         87593        87593     200.0  ⋯
#    2 │ river8      river9          river         87593        87593     200.0
#    3 │ river8      infrastructure  river         87593        87593     200.0
#    4 │ river7      river8          river         87593        87593     200.0
#    5 │ river6      river7          river         87593        87593     200.0  ⋯
#    6 │ dam         river6          dam           87593        87593     200.0
#    7 │ river5      dam             river         87593        87593     200.0
#    8 │ river4      river5          river         87593        87593     200.0
#    9 │ river3      river4          river         87593        87593    1166.64 ⋯
#   10 │ river2      river3          river         87593        87593    1171.15
#   11 │ landslide   river9          landslide     87595        87593    1050.34
#   12 │ landslide   infrastructure  landslide     87595        87593    2054.92
#   13 │ catchment1  river1          catchment     87601        87593    1071.15 ⋯
#   14 │ catchment2  river2          catchment     87601        87593    1066.64
#   15 │ river1      river2          river         87593        87593     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river         87594        87594     200.0  ⋯
#    2 │ river8      river9          river         87594        87594     200.0
#    3 │ river8      infrastructure  river         87594        87594     200.0
#    4 │ river7      river8          river         87594        87594     200.0
#    5 │ river6      river7          river         87594        87594     200.0  ⋯
#    6 │ dam         river6          dam           87594        87594     200.0
#    7 │ river5      dam             river         87594        87594     200.0
#    8 │ river4      river5          river         87594        87594    1166.64
#    9 │ river3      river4          river         87594        87594    1171.15 ⋯
#   10 │ river2      river3          river         87594        87594     200.0
#   11 │ landslide   river9          landslide     87595        87594    1050.34
#   12 │ landslide   infrastructure  landslide     87595        87594    2054.92
#   13 │ catchment1  river1          catchment     87601        87594    1071.15 ⋯
#   14 │ catchment2  river2          catchment     87601        87594    1066.64
#   15 │ river1      river2          river         87594        87594     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river         87595        87595     200.0  ⋯
#    2 │ river8      river9          river         87595        87595     200.0
#    3 │ river8      infrastructure  river         87595        87595     200.0
#    4 │ river7      river8          river         87595        87595     200.0
#    5 │ river6      river7          river         87595        87595     200.0  ⋯
#    6 │ dam         river6          dam           87595        87595     200.0
#    7 │ river5      dam             river         87595        87595    1166.64
#    8 │ river4      river5          river         87595        87595    1171.15
#    9 │ river3      river4          river         87595        87595     200.0  ⋯
#   10 │ river2      river3          river         87595        87595     200.0
#   11 │ landslide   river9          landslide     87595        87595    1050.34
#   12 │ landslide   infrastructure  landslide     87595        87595    2054.92
#   13 │ catchment1  river1          catchment     87601        87595    1071.15 ⋯
#   14 │ catchment2  river2          catchment     87601        87595    1066.64
#   15 │ river1      river2          river         87595        87595     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river         87596        87596     200.0  ⋯
#    2 │ river8      river9          river         87596        87596     200.0
#    3 │ river8      infrastructure  river         87596        87596     200.0
#    4 │ river7      river8          river         87596        87596     200.0
#    5 │ river6      river7          river         87596        87596     200.0  ⋯
#    6 │ dam         river6          dam           87596        87596    1166.64
#    7 │ river5      dam             river         87596        87596    1171.15
#    8 │ river4      river5          river         87596        87596     200.0
#    9 │ river3      river4          river         87596        87596     200.0  ⋯
#   10 │ river2      river3          river         87596        87596     200.0
#   11 │ landslide   river9          landslide     87598        87596    1550.68
#   12 │ landslide   infrastructure  landslide     87598        87596    1101.72
#   13 │ catchment1  river1          catchment     87601        87596    1071.15 ⋯
#   14 │ catchment2  river2          catchment     87601        87596    1066.64
#   15 │ river1      river2          river         87596        87596     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river         87597        87597     200.0  ⋯
#    2 │ river8      river9          river         87597        87597     200.0
#    3 │ river8      infrastructure  river         87597        87597     200.0
#    4 │ river7      river8          river         87597        87597     200.0
#    5 │ river6      river7          river         87597        87597    1166.64 ⋯
#    6 │ dam         river6          dam           87597        87597    1171.15
#    7 │ river5      dam             river         87597        87597     200.0
#    8 │ river4      river5          river         87597        87597     200.0
#    9 │ river3      river4          river         87597        87597     200.0  ⋯
#   10 │ river2      river3          river         87597        87597     200.0
#   11 │ landslide   river9          landslide     87598        87597    1550.68
#   12 │ landslide   infrastructure  landslide     87598        87597    1101.72
#   13 │ catchment1  river1          catchment     87601        87597    1071.15 ⋯
#   14 │ catchment2  river2          catchment     87601        87597    1066.64
#   15 │ river1      river2          river         87597        87597     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river         87598        87598     200.0  ⋯
#    2 │ river8      river9          river         87598        87598     200.0
#    3 │ river8      infrastructure  river         87598        87598     200.0
#    4 │ river7      river8          river         87598        87598    1166.64
#    5 │ river6      river7          river         87598        87598    1171.15 ⋯
#    6 │ dam         river6          dam           87598        87598     200.0
#    7 │ river5      dam             river         87598        87598     200.0
#    8 │ river4      river5          river         87598        87598     200.0
#    9 │ river3      river4          river         87598        87598     200.0  ⋯
#   10 │ river2      river3          river         87598        87598     200.0
#   11 │ landslide   river9          landslide     87598        87598    1550.68
#   12 │ landslide   infrastructure  landslide     87598        87598    1101.72
#   13 │ catchment1  river1          catchment     87601        87598    1071.15 ⋯
#   14 │ catchment2  river2          catchment     87601        87598    1066.64
#   15 │ river1      river2          river         87598        87598     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river         87599        87599     200.0  ⋯
#    2 │ river8      river9          river         87599        87599    1166.64
#    3 │ river8      infrastructure  river         87599        87599    1166.64
#    4 │ river7      river8          river         87599        87599    1171.15
#    5 │ river6      river7          river         87599        87599     200.0  ⋯
#    6 │ dam         river6          dam           87599        87599     200.0
#    7 │ river5      dam             river         87599        87599     200.0
#    8 │ river4      river5          river         87599        87599     200.0
#    9 │ river3      river4          river         87599        87599     200.0  ⋯
#   10 │ river2      river3          river         87599        87599     200.0
#   11 │ landslide   river9          landslide     87601        87599    1062.12
#   12 │ landslide   infrastructure  landslide     87601        87599    1316.13
#   13 │ catchment1  river1          catchment     87601        87599    1071.15 ⋯
#   14 │ catchment2  river2          catchment     87601        87599    1066.64
#   15 │ river1      river2          river         87599        87599     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river         87600        87600    1166.64 ⋯
#    2 │ river8      river9          river         87600        87600    1171.15
#    3 │ river8      infrastructure  river         87600        87600    1171.15
#    4 │ river7      river8          river         87600        87600     200.0
#    5 │ river6      river7          river         87600        87600     200.0  ⋯
#    6 │ dam         river6          dam           87600        87600     200.0
#    7 │ river5      dam             river         87600        87600     200.0
#    8 │ river4      river5          river         87600        87600     200.0
#    9 │ river3      river4          river         87600        87600     200.0  ⋯
#   10 │ river2      river3          river         87600        87600     200.0
#   11 │ landslide   river9          landslide     87601        87600    1062.12
#   12 │ landslide   infrastructure  landslide     87601        87600    1316.13
#   13 │ catchment1  river1          catchment     87601        87600    1071.15 ⋯
#   14 │ catchment2  river2          catchment     87601        87600    1066.64
#   15 │ river1      river2          river         87600        87600     100.0
#  15×6 DataFrame
#  Row │ source      target          type_source  time    global_time  magnitude ⋯
#      │ String?     String?         String?      Int64?  Int64?       Float64   ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │ river9      river10         river         87601        87600    1171.15 ⋯
#    2 │ river8      river9          river         87601        87600     200.0
#    3 │ river8      infrastructure  river         87601        87600     200.0
#    4 │ river7      river8          river         87601        87600     200.0
#    5 │ river6      river7          river         87601        87600     200.0  ⋯
#    6 │ dam         river6          dam           87601        87600     200.0
#    7 │ river5      dam             river         87601        87600     200.0
#    8 │ river4      river5          river         87601        87600     200.0
#    9 │ river3      river4          river         87601        87600     200.0  ⋯
#   10 │ river2      river3          river         87601        87600     200.0
#   11 │ landslide   river9          landslide     87601        87600    1062.12
#   12 │ landslide   infrastructure  landslide     87601        87600    1316.13
#   13 │ catchment1  river1          catchment     87601        87600    1071.15 ⋯
#   14 │ catchment2  river2          catchment     87601        87600    1066.64
#   15 │ river1      river2          river         87601        87600     100.0
